# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import os
from stockstats import StockDataFrame as Sdf
import stockstats

# %% [markdown]
# ## XRP

# %% [markdown]
# ### Creating Target Variable

# %%
df = pd.read_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Merged\XRP_merged.csv')

df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name      open      high       low     close  \
# 360           4 2025-07-11  2781  2.546631  2.964270  2.517547  2.734864
# 361           3 2025-07-12  2781  2.734850  2.841254  2.669910  2.737636
# 362           2 2025-07-13  2781  2.737636  2.878500  2.726897  2.835941
# 363           1 2025-07-14  2781  2.835923  3.021792  2.827182  2.954977
# 364           0 2025-07-15  2781  2.954884  2.957473  2.808502  2.918952
#
#            volume     marketCap  daily_weighted_sentiment  comment_volume  \
# 360  1.578910e+10  1.617161e+11                 -0.256150            49.0
# 361  8.647115e+09  1.618808e+11                  0.024163            37.0
# 362  7.159804e+09  1.676928e+11                 -0.075498            93.0
# 363  1.239316e+10  1.747271e+11                  0.531816             3.0
# 364  8.879750e+09  1.726021e+11                 -0.034089            46.0
#
#      XRP_trends    gold_spot    gspc_spot     ndx_spot
# 360        33.0  3356.000000  6259.750000  22780.59961
# 361        33.0  3356.000000  6259.750000  22780.59961
# 362        63.0  3356.000000  6259.750000  22780.59961
# 363        63.0  3351.500000  6268.560059  22855.63086
# 364        63.0  3329.800049  6243.759766  22884.58984

# %%
def assign_target(change):
    if pd.isna(change):
        return np.nan  
    elif change > 0:
        return 1       
    else:
        return -1

# %%
df['price_change'] = df['close'].diff()
df['next_day_price_change'] = df['price_change'].shift(-1)

# %%
df['target'] = df['next_day_price_change'].apply(assign_target)
df.drop(columns=['next_day_price_change'], inplace=True)
df.dropna(subset=['target'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0       date  name      open      high       low     close  \
# 0         364 2024-07-16  2781  0.537753  0.592527  0.534284  0.579376
# 1         363 2024-07-17  2781  0.579373  0.636644  0.579373  0.626486
# 2         362 2024-07-18  2781  0.626589  0.635987  0.560432  0.569574
# 3         361 2024-07-19  2781  0.569608  0.586012  0.542638  0.573752
# 4         360 2024-07-20  2781  0.573729  0.603782  0.571832  0.594651
#
#          volume     marketCap  daily_weighted_sentiment  comment_volume  \
# 0  3.380662e+09  3.233226e+10                  0.000000             0.0
# 1  3.708255e+09  3.502649e+10                 -0.046500             8.0
# 2  2.986712e+09  3.184459e+10                 -0.046500             8.0
# 3  2.340175e+09  3.207691e+10                 -0.007005            32.0
# 4  1.538359e+09  3.324672e+10                 -0.007005            32.0
#
#    XRP_trends    gold_spot    gspc_spot     ndx_spot  price_change  target
# 0        25.0  2462.399902  5667.200195  20398.61914           NaN     1.0
# 1        25.0  2454.800049  5588.270020  19799.14063      0.047110    -1.0
# 2        25.0  2451.800049  5544.589844  19705.08984     -0.056912     1.0
# 3        25.0  2395.500000  5505.000000  19522.61914      0.004178     1.0
# 4        25.0  2395.500000  5505.000000  19522.61914      0.020899     1.0

# %% [markdown]
# ### Percentage Changes (24h, 3days, 7days)

# %%
df['percent_change_24h'] = df['close'].pct_change() * 100
df['percent_change_3d'] = df['close'].pct_change(periods=3) * 100
df['percent_change_7d'] = df['close'].pct_change(periods=7) * 100
df['percent_change_14d'] = df['close'].pct_change(periods=14) * 100

# %% [markdown]
# ### Moving Average

# %% [markdown]
# ma_7d: This feature tells the model about the level of the recent price trend. It acts as a smoothed, less noisy version of the price itself. Currently taken for 7 Days.
#
# price_vs_ma7d: This feature tells the model about the deviation from the recent trend. It measures how "overextended" or "oversold" the current price is compared to its recent average. A model might learn that when this value is extremely high (e.g., +15%), the price is likely to come back down, even if the trend is generally up.

# %%
df['ma_7d'] = df['close'].rolling(window=7).mean()
df['price_vs_ma7d'] = (df['close'] - df['ma_7d']) / df['ma_7d'] * 100

# %%
df['ma_14d'] = df['close'].rolling(window=14).mean()
df['price_vs_ma14d'] = (df['close'] - df['ma_14d']) / df['ma_14d'] * 100

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name      open      high       low     close  \
# 359           5 2025-07-10  2781  2.405636  2.558056  2.397295  2.546683
# 360           4 2025-07-11  2781  2.546631  2.964270  2.517547  2.734864
# 361           3 2025-07-12  2781  2.734850  2.841254  2.669910  2.737636
# 362           2 2025-07-13  2781  2.737636  2.878500  2.726897  2.835941
# 363           1 2025-07-14  2781  2.835923  3.021792  2.827182  2.954977
#
#            volume     marketCap  daily_weighted_sentiment  ...  price_change  \
# 359  6.049788e+09  1.504249e+11                 -0.187919  ...      0.141047
# 360  1.578910e+10  1.617161e+11                 -0.256150  ...      0.188181
# 361  8.647115e+09  1.618808e+11                  0.024163  ...      0.002772
# 362  7.159804e+09  1.676928e+11                 -0.075498  ...      0.098305
# 363  1.239316e+10  1.747271e+11                  0.531816  ...      0.119036
#
#      target  percent_change_24h  percent_change_3d  percent_change_7d  \
# 359     1.0            5.863172          11.987475          12.801976
# 360     1.0            7.389261          18.329176          23.128911
# 361     1.0            0.101353          13.800902          23.399103
# 362     1.0            3.590885          11.358236          24.791642
# 363    -1.0            4.197407           8.048415          29.941748
#
#      percent_change_14d     ma_7d  price_vs_ma7d    ma_14d  price_vs_ma14d
# 359           20.933426  2.321405       9.704393  2.263424       12.514601
# 360           27.641165  2.394794      14.200385  2.305727       18.611754
# 361           25.232408  2.468953      10.882453  2.345127       16.737210
# 362           28.493306  2.549439      11.237855  2.390046       18.656335
# 363           31.992268  2.646710      11.647176  2.441205       21.045831
#
# [5 rows x 25 columns]

# %%
df.head(15)
# Out:
#     Unnamed: 0       date  name      open      high       low     close  \
# 0          364 2024-07-16  2781  0.537753  0.592527  0.534284  0.579376
# 1          363 2024-07-17  2781  0.579373  0.636644  0.579373  0.626486
# 2          362 2024-07-18  2781  0.626589  0.635987  0.560432  0.569574
# 3          361 2024-07-19  2781  0.569608  0.586012  0.542638  0.573752
# 4          360 2024-07-20  2781  0.573729  0.603782  0.571832  0.594651
# 5          359 2024-07-21  2781  0.594653  0.607188  0.575616  0.597467
# 6          358 2024-07-22  2781  0.597480  0.622663  0.586667  0.607637
# 7          357 2024-07-23  2781  0.607637  0.616576  0.584276  0.597457
# 8          356 2024-07-24  2781  0.597460  0.632155  0.592577  0.618843
# 9          355 2024-07-25  2781  0.618852  0.623824  0.586939  0.599816
# 10         354 2024-07-26  2781  0.599814  0.608454  0.587459  0.604068
# 11         353 2024-07-27  2781  0.604069  0.608871  0.586704  0.596795
# 12         352 2024-07-28  2781  0.596795  0.612916  0.592157  0.601947
# 13         351 2024-07-29  2781  0.601944  0.611412  0.593301  0.602086
# 14         350 2024-07-30  2781  0.602084  0.634965  0.596157  0.627877
#
#           volume     marketCap  daily_weighted_sentiment  ...  price_change  \
# 0   3.380662e+09  3.233226e+10                  0.000000  ...           NaN
# 1   3.708255e+09  3.502649e+10                 -0.046500  ...      0.047110
# 2   2.986712e+09  3.184459e+10                 -0.046500  ...     -0.056912
# 3   2.340175e+09  3.207691e+10                 -0.007005  ...      0.004178
# 4   1.538359e+09  3.324672e+10                 -0.007005  ...      0.020899
# 5   1.489477e+09  3.340477e+10                 -0.007005  ...      0.002816
# 6   2.052124e+09  3.397267e+10                 -0.148717  ...      0.010170
# 7   1.657693e+09  3.340365e+10                 -0.142015  ...     -0.010180
# 8   1.933085e+09  3.459969e+10                 -0.142015  ...      0.021386
# 9   2.306854e+09  3.356612e+10                 -0.142015  ...     -0.019027
# 10  1.385845e+09  3.380422e+10                 -0.142015  ...      0.004252
# 11  1.007994e+09  3.339717e+10                  0.000000  ...     -0.007273
# 12  9.160293e+08  3.368532e+10                 -0.668340  ...      0.005151
# 13  1.178431e+09  3.369313e+10                  0.063392  ...      0.000140
# 14  2.197506e+09  3.513567e+10                 -0.075888  ...      0.025791
#
#     target  percent_change_24h  percent_change_3d  percent_change_7d  \
# 0      1.0                 NaN                NaN                NaN
# 1     -1.0            8.131156                NaN                NaN
# 2      1.0           -9.084272                NaN                NaN
# 3      1.0            0.733586          -0.970597                NaN
# 4      1.0            3.642530          -5.081401                NaN
# 5      1.0            0.473477           4.897160                NaN
# 6     -1.0            1.702202           5.905812                NaN
# 7      1.0           -1.675346           0.471808           3.120826
# 8     -1.0            3.579574           3.577853          -1.219856
# 9      1.0           -3.074654          -1.287101           5.309608
# 10    -1.0            0.708884           1.106544           5.283784
# 11     1.0           -1.204015          -3.562834           0.360491
# 12     1.0            0.863192           0.355179           0.749768
# 13     1.0            0.023186          -0.328111          -0.913525
# 14    -1.0            4.283655           5.208211           5.091646
#
#     percent_change_14d     ma_7d  price_vs_ma7d    ma_14d  price_vs_ma14d
# 0                  NaN       NaN            NaN       NaN             NaN
# 1                  NaN       NaN            NaN       NaN             NaN
# 2                  NaN       NaN            NaN       NaN             NaN
# 3                  NaN       NaN            NaN       NaN             NaN
# 4                  NaN       NaN            NaN       NaN             NaN
# 5                  NaN       NaN            NaN       NaN             NaN
# 6                  NaN  0.592706       2.519105       NaN             NaN
# 7                  NaN  0.595289       0.364163       NaN             NaN
# 8                  NaN  0.594197       4.147777       NaN             NaN
# 9                  NaN  0.598518       0.216933       NaN             NaN
# 10                 NaN  0.602849       0.202298       NaN             NaN
# 11                 NaN  0.603155      -1.054415       NaN             NaN
# 12                 NaN  0.603795      -0.306100       NaN             NaN
# 13                 NaN  0.603002      -0.151850  0.597854        0.707892
# 14            8.371374  0.607348       3.380249  0.601318        4.416802
#
# [15 rows x 25 columns]

# %% [markdown]
# ### Stockstats Features

# %%
df.rename(columns={
    'Close': 'close',
    'High': 'high',
    'Low': 'low',
    'Open': 'open',
    'Volume': 'volume'
}, inplace=True)

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
stock_df = Sdf.retype(df)

# %%
stock_df['close_7_ema']
stock_df['close_14_ema']
stock_df['adx']
stock_df['rsi_7']
stock_df['rsi']
stock_df['stochrsi']
stock_df['atr']
stock_df['mfi']
# Out:
# date
# 2024-07-16    0.500000
# 2024-07-17    0.500000
# 2024-07-18    0.500000
# 2024-07-19    0.500000
# 2024-07-20    0.500000
#                 ...
# 2025-07-10    0.800784
# 2025-07-11    0.898932
# 2025-07-12    0.911115
# 2025-07-13    0.919541
# 2025-07-14    0.930483
# Name: mfi, Length: 364, dtype: float64

# %%
stock_df['boll']
stock_df['boll_width'] = stock_df['boll_ub'] - stock_df['boll_lb']

# %%
stock_df['kdjk']
stock_df['kdjd']

#Checking if k line is over d line
stock_df['k_above_d'] = stock_df['kdjk'] > stock_df['kdjd']
stock_df['crossover'] = stock_df['k_above_d'].diff()

stock_df['kdj_signal'] = 0.0
# For Bullish signal
stock_df.loc[stock_df['crossover'] & stock_df['k_above_d'], 'kdj_signal'] = 1.0
# For Bearish signal
stock_df.loc[stock_df['crossover'] & ~stock_df['k_above_d'], 'kdj_signal'] = -1.0

stock_df = stock_df.drop(['k_above_d', 'crossover'], axis=1)

print(stock_df[['kdjk', 'kdjd', 'kdj_signal']].tail(10))
# Out:
#                  kdjk       kdjd  kdj_signal
# date
# 2025-07-05  64.725562  68.088455         0.0
# 2025-07-06  67.788060  67.988323         0.0
# 2025-07-07  65.935610  67.304085         0.0
# 2025-07-08  70.984244  68.530805         1.0
# 2025-07-09  78.496332  71.852647         0.0
# 2025-07-10  84.705485  76.136926         0.0
# 2025-07-11  79.791463  77.355105         0.0
# 2025-07-12  76.636424  77.115545        -1.0
# 2025-07-13  78.800563  77.677217         1.0
# 2025-07-14  83.118311  79.490915         0.0

# %%
window=stockstats.set_dft_window('macd', (8, 20, 9))
stockstats.set_dft_window('macd', window)
# Out:
# (8, 20, 9)

# %%
stock_df = Sdf.retype(stock_df)

# %%
stock_df['macd']
# Out:
# date
# 2024-07-16    0.000000
# 2024-07-17    0.001057
# 2024-07-18   -0.000418
# 2024-07-19   -0.000928
# 2024-07-20   -0.000354
#                 ...
# 2025-07-10    0.052895
# 2025-07-11    0.083217
# 2025-07-12    0.106246
# 2025-07-13    0.130920
# 2025-07-14    0.158256
# Name: macd, Length: 364, dtype: float64

# %%
stock_df.head()
# Out:
#             name      open      high       low     close        volume  \
# date
# 2024-07-16  2781  0.537753  0.592527  0.534284  0.579376  3.380662e+09
# 2024-07-17  2781  0.579373  0.636644  0.579373  0.626486  3.708255e+09
# 2024-07-18  2781  0.626589  0.635987  0.560432  0.569574  2.986712e+09
# 2024-07-19  2781  0.569608  0.586012  0.542638  0.573752  2.340175e+09
# 2024-07-20  2781  0.573729  0.603782  0.571832  0.594651  1.538359e+09
#
#                marketCap  daily_weighted_sentiment  comment_volume  \
# date
# 2024-07-16  3.233226e+10                  0.000000             0.0
# 2024-07-17  3.502649e+10                 -0.046500             8.0
# 2024-07-18  3.184459e+10                 -0.046500             8.0
# 2024-07-19  3.207691e+10                 -0.007005            32.0
# 2024-07-20  3.324672e+10                 -0.007005            32.0
#
#             XRP_trends  ...      boll   boll_ub   boll_lb  boll_width  \
# date                    ...
# 2024-07-16        25.0  ...  0.579376       NaN       NaN         NaN
# 2024-07-17        25.0  ...  0.602931  0.669554  0.536307    0.133247
# 2024-07-18        25.0  ...  0.591812  0.652663  0.530960    0.121703
# 2024-07-19        25.0  ...  0.587297  0.640162  0.534432    0.105731
# 2024-07-20        25.0  ...  0.588768  0.635021  0.542515    0.092506
#
#                  kdjk       kdjd  kdj_signal      macd     macds     macdh
# date
# 2024-07-16  59.140213  53.046738         0.0  0.000000  0.000000  0.000000
# 2024-07-17  69.452250  58.515242         0.0  0.001057  0.000587  0.000470
# 2024-07-18  57.793719  58.274734        -1.0 -0.000418  0.000175 -0.000593
# 2024-07-19  51.382028  55.977166         0.0 -0.000928 -0.000198 -0.000729
# 2024-07-20  53.913337  55.289223         0.0 -0.000354 -0.000245 -0.000109
#
# [5 rows x 43 columns]

# %%
all_features_df = pd.DataFrame(stock_df)

# %%
all_features_df.dropna(inplace=True)

# %%
all_features_df.to_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Feature Engineering\FeatureEngineered_XRP.csv')
