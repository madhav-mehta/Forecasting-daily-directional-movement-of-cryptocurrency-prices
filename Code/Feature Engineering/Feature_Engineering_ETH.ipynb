# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import os
from stockstats import StockDataFrame as Sdf
import stockstats

# %% [markdown]
# ## ETH

# %% [markdown]
# ### Creating Target Variable

# %%
df = pd.read_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Merged\ETH_merged.csv')

df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name         open         high          low  \
# 360           4 2025-07-11  2781  2954.832779  3038.141150  2916.956467
# 361           3 2025-07-12  2781  2958.333774  2979.779932  2907.193557
# 362           2 2025-07-13  2781  2942.853579  3016.393465  2938.736541
# 363           1 2025-07-14  2781  2973.225148  3079.985511  2965.323790
# 364           0 2025-07-15  2781  3013.293577  3142.427222  2934.371234
#
#            close        volume     marketCap  daily_weighted_sentiment  \
# 360  2957.886198  3.622656e+10  3.571174e+11                  0.313511
# 361  2942.911663  1.631720e+10  3.552472e+11                 -0.004126
# 362  2973.358989  1.736175e+10  3.589131e+11                 -0.129803
# 363  3013.350859  3.634929e+10  3.637496e+11                  0.040624
# 364  3139.889718  3.901366e+10  3.790302e+11                 -0.065852
#
#      comment_volume  ETH_trends    gold_spot    gspc_spot     ndx_spot
# 360           113.0        62.0  3356.000000  6259.750000  22780.59961
# 361            55.0        62.0  3356.000000  6259.750000  22780.59961
# 362            74.0       100.0  3356.000000  6259.750000  22780.59961
# 363            44.0       100.0  3351.500000  6268.560059  22855.63086
# 364            44.0       100.0  3329.800049  6243.759766  22884.58984

# %%
def assign_target(change):
    if pd.isna(change):
        return np.nan  
    elif change > 0:
        return 1       
    else:
        return -1

# %%
df['price_change'] = df['close'].diff()
df['next_day_price_change'] = df['price_change'].shift(-1)

# %%
df['target'] = df['next_day_price_change'].apply(assign_target)
df.drop(columns=['next_day_price_change'], inplace=True)
df.dropna(subset=['target'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0       date  name         open         high          low  \
# 0         364 2024-07-16  2781  3486.144073  3498.219053  3351.779683
# 1         363 2024-07-17  2781  3446.736719  3516.104210  3379.099525
# 2         362 2024-07-18  2781  3388.030068  3488.715655  3374.990430
# 3         361 2024-07-19  2781  3425.908810  3540.588346  3377.877575
# 4         360 2024-07-20  2781  3505.721336  3539.904292  3482.488908
#
#          close        volume     marketCap  daily_weighted_sentiment  \
# 0  3443.513502  2.044666e+10  4.139778e+11                  0.030913
# 1  3388.752373  1.673912e+10  4.073999e+11                  0.030913
# 2  3426.258591  1.503562e+10  4.119142e+11                  0.089105
# 3  3505.734841  1.770563e+10  4.214725e+11                  0.016569
# 4  3519.295344  1.036020e+10  4.231267e+11                  0.000000
#
#    comment_volume  ETH_trends    gold_spot    gspc_spot     ndx_spot  \
# 0            17.0        57.0  2462.399902  5667.200195  20398.61914
# 1            17.0        57.0  2454.800049  5588.270020  19799.14063
# 2            45.0        57.0  2451.800049  5544.589844  19705.08984
# 3            33.0        57.0  2395.500000  5505.000000  19522.61914
# 4            32.0        57.0  2395.500000  5505.000000  19522.61914
#
#    price_change  target
# 0           NaN    -1.0
# 1    -54.761129     1.0
# 2     37.506218     1.0
# 3     79.476250     1.0
# 4     13.560503     1.0

# %% [markdown]
# ### Percentage Changes (24h, 3days, 7days)

# %%
df['percent_change_24h'] = df['close'].pct_change() * 100
df['percent_change_3d'] = df['close'].pct_change(periods=3) * 100
df['percent_change_7d'] = df['close'].pct_change(periods=7) * 100
df['percent_change_14d'] = df['close'].pct_change(periods=14) * 100

# %% [markdown]
# ### Moving Average

# %% [markdown]
# ma_7d: This feature tells the model about the level of the recent price trend. It acts as a smoothed, less noisy version of the price itself. Currently taken for 7 Days.
#
# price_vs_ma7d: This feature tells the model about the deviation from the recent trend. It measures how "overextended" or "oversold" the current price is compared to its recent average. A model might learn that when this value is extremely high (e.g., +15%), the price is likely to come back down, even if the trend is generally up.

# %%
df['ma_7d'] = df['close'].rolling(window=7).mean()
df['price_vs_ma7d'] = (df['close'] - df['ma_7d']) / df['ma_7d'] * 100

# %%
df['ma_14d'] = df['close'].rolling(window=14).mean()
df['price_vs_ma14d'] = (df['close'] - df['ma_14d']) / df['ma_14d'] * 100

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name         open         high          low  \
# 359           5 2025-07-10  2781  2770.737301  2995.152156  2757.266597
# 360           4 2025-07-11  2781  2954.832779  3038.141150  2916.956467
# 361           3 2025-07-12  2781  2958.333774  2979.779932  2907.193557
# 362           2 2025-07-13  2781  2942.853579  3016.393465  2938.736541
# 363           1 2025-07-14  2781  2973.225148  3079.985511  2965.323790
#
#            close        volume     marketCap  daily_weighted_sentiment  ...  \
# 359  2954.845218  3.392920e+10  3.566962e+11                 -0.205187  ...
# 360  2957.886198  3.622656e+10  3.571174e+11                  0.313511  ...
# 361  2942.911663  1.631720e+10  3.552472e+11                 -0.004126  ...
# 362  2973.358989  1.736175e+10  3.589131e+11                 -0.129803  ...
# 363  3013.350859  3.634929e+10  3.637496e+11                  0.040624  ...
#
#      price_change  target  percent_change_24h  percent_change_3d  \
# 359    184.067584     1.0            6.643174          16.194645
# 360      3.040981    -1.0            0.102915          13.090410
# 361    -14.974536     1.0           -0.506258           6.212481
# 362     30.447326     1.0            1.034599           0.626556
# 363     39.991871     1.0            1.345006           1.875145
#
#      percent_change_7d  percent_change_14d        ma_7d  price_vs_ma7d  \
# 359          14.042336           22.295770  2640.168080      11.918830
# 360          17.913683           22.031712  2704.363508       9.374579
# 361          16.908395           20.754184  2765.168029       6.427951
# 362          15.639266           18.888705  2822.614101       5.340613
# 363          18.495287           21.190190  2889.805189       4.275225
#
#           ma_14d  price_vs_ma14d
# 359  2564.122348       15.238074
# 360  2602.266587       13.665764
# 361  2638.395314       11.541726
# 362  2672.138097       11.272654
# 363  2709.772848       11.203080
#
# [5 rows x 25 columns]

# %%
df.head(15)
# Out:
#     Unnamed: 0       date  name         open         high          low  \
#
#     percent_change_7d  percent_change_14d        ma_7d  price_vs_ma7d  \
# 0                 NaN                 NaN          NaN            NaN
# 1                 NaN                 NaN          NaN            NaN
# 2                 NaN                 NaN          NaN            NaN
# 3                 NaN                 NaN          NaN            NaN
# 4                 NaN                 NaN          NaN            NaN
# 5                 NaN                 NaN          NaN            NaN
# 6                 NaN                 NaN  3465.797140      -0.732220
# 7            1.117535                 NaN  3471.294634       0.308280
# 8           -1.546674                 NaN  3463.807069      -3.679987
# 9           -7.350037                 NaN  3427.831173      -7.392542
# 10          -6.554501                 NaN  3395.004971      -3.506727
# 11          -7.719936                 NaN  3356.192490      -3.235348
# 12          -7.497042                 NaN  3318.315233      -1.411879
# 13          -3.484478                 NaN  3301.189421       0.586146
# 14          -5.839414           -4.787137  3272.142541       0.199418
#
#          ma_14d  price_vs_ma14d
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           NaN             NaN
# 7           NaN             NaN
# 8           NaN             NaN
# 9           NaN             NaN
# 10          NaN             NaN
# 11          NaN             NaN
# 12          NaN             NaN
# 13  3383.493281       -1.860623
# 14  3371.718587       -2.759744
#
# [15 rows x 25 columns]

# %% [markdown]
# ### Stockstats Features

# %%
df.rename(columns={
    'Close': 'close',
    'High': 'high',
    'Low': 'low',
    'Open': 'open',
    'Volume': 'volume'
}, inplace=True)

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
stock_df = Sdf.retype(df)

# %%
stock_df['close_7_ema']
stock_df['close_14_ema']
stock_df['adx']
stock_df['rsi_7']
stock_df['rsi']
stock_df['stochrsi']
stock_df['atr']
stock_df['mfi']
# Out:
# date
# 2024-07-16    0.500000
# 2024-07-17    0.500000
# 2024-07-18    0.500000
# 2024-07-19    0.500000
# 2024-07-20    0.500000
#                 ...
# 2025-07-10    0.708691
# 2025-07-11    0.789401
# 2025-07-12    0.732622
# 2025-07-13    0.739863
# 2025-07-14    0.761125
# Name: mfi, Length: 364, dtype: float64

# %%
stock_df['boll']
stock_df['boll_width'] = stock_df['boll_ub'] - stock_df['boll_lb']

# %%
stock_df['kdjk']
stock_df['kdjd']

#Checking if k line is over d line
stock_df['k_above_d'] = stock_df['kdjk'] > stock_df['kdjd']
stock_df['crossover'] = stock_df['k_above_d'].diff()

stock_df['kdj_signal'] = 0.0
# For Bullish signal
stock_df.loc[stock_df['crossover'] & stock_df['k_above_d'], 'kdj_signal'] = 1.0
# For Bearish signal
stock_df.loc[stock_df['crossover'] & ~stock_df['k_above_d'], 'kdj_signal'] = -1.0

stock_df = stock_df.drop(['k_above_d', 'crossover'], axis=1)

print(stock_df[['kdjk', 'kdjd', 'kdj_signal']].tail(10))
# Out:
#                  kdjk       kdjd  kdj_signal
# date
# 2025-07-05  64.206001  69.521705         0.0
# 2025-07-06  67.835674  68.959695         0.0
# 2025-07-07  66.591984  68.170458         0.0
# 2025-07-08  75.172632  70.504516         1.0
# 2025-07-09  81.546672  74.185235         0.0
# 2025-07-10  85.519353  77.963274         0.0
# 2025-07-11  85.589425  80.505324         0.0
# 2025-07-12  84.748580  81.919743         0.0
# 2025-07-13  85.900037  83.246507         0.0
# 2025-07-14  86.734556  84.409190         0.0

# %%
window=stockstats.set_dft_window('macd', (8, 20, 9))
stockstats.set_dft_window('macd', window)
# Out:
# (8, 20, 9)

# %%
stock_df = Sdf.retype(stock_df)

# %%
stock_df['macd']
# Out:
# date
# 2024-07-16      0.000000
# 2024-07-17     -1.228615
# 2024-07-18     -0.402434
# 2024-07-19      2.852652
# 2024-07-20      5.100965
#                  ...
# 2025-07-10     66.939518
# 2025-07-11     88.561261
# 2025-07-12    103.297578
# 2025-07-13    116.094792
# 2025-07-14    127.988316
# Name: macd, Length: 364, dtype: float64

# %%
stock_df.head()
# Out:
#             name         open         high          low        close  \
# date
# 2024-07-16  2781  3486.144073  3498.219053  3351.779683  3443.513502
# 2024-07-17  2781  3446.736719  3516.104210  3379.099525  3388.752373
# 2024-07-18  2781  3388.030068  3488.715655  3374.990430  3426.258591
# 2024-07-19  2781  3425.908810  3540.588346  3377.877575  3505.734841
# 2024-07-20  2781  3505.721336  3539.904292  3482.488908  3519.295344
#
#                   volume     marketCap  daily_weighted_sentiment  \
# date
# 2024-07-16  2.044666e+10  4.139778e+11                  0.030913
# 2024-07-17  1.673912e+10  4.073999e+11                  0.030913
# 2024-07-18  1.503562e+10  4.119142e+11                  0.089105
# 2024-07-19  1.770563e+10  4.214725e+11                  0.016569
# 2024-07-20  1.036020e+10  4.231267e+11                  0.000000
#
#             comment_volume  ETH_trends  ...         boll      boll_ub  \
# date                                    ...
# 2024-07-16            17.0        57.0  ...  3443.513502          NaN
# 2024-07-17            17.0        57.0  ...  3416.132937  3493.576868
# 2024-07-18            45.0        57.0  ...  3419.508155  3475.503569
# 2024-07-19            33.0        57.0  ...  3441.064827  3538.662806
# 2024-07-20            32.0        57.0  ...  3456.710930  3566.438025
#
#                 boll_lb  boll_width       kdjk       kdjd  kdj_signal  \
# date
# 2024-07-16          NaN         NaN  54.214289  51.404763         0.0
# 2024-07-17  3338.689007  154.887862  43.642793  48.817439        -1.0
# 2024-07-18  3363.512742  111.990827  44.203288  47.279389         0.0
# 2024-07-19  3343.466847  195.195959  56.648960  50.402579         1.0
# 2024-07-20  3346.983836  219.454189  67.340122  56.048427         0.0
#
#                 macd     macds     macdh
# date
# 2024-07-16  0.000000  0.000000  0.000000
# 2024-07-17 -1.228615 -0.682564 -0.546051
# 2024-07-18 -0.402434 -0.567757  0.165323
# 2024-07-19  2.852652  0.590918  2.261733
# 2024-07-20  5.100965  1.932555  3.168410
#
# [5 rows x 43 columns]

# %%
all_features_df = pd.DataFrame(stock_df)

# %%
all_features_df.dropna(inplace=True)

# %%
all_features_df.to_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Feature Engineering\FeatureEngineered_ETH.csv')
