# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import os
from stockstats import StockDataFrame as Sdf
import stockstats

# %% [markdown]
# ## BTC

# %% [markdown]
# ### Creating Target Variable

# %%
df = pd.read_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Merged\BTC_merged.csv')

df['date'] = pd.to_datetime(df['date'])
df.sort_values(by='date', inplace=True)

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name           open           high            low  \
# 360           4 2025-07-11  2781  115986.234797  118856.473739  115245.686349
# 361           3 2025-07-12  2781  117530.712896  118219.900043  116977.023698
# 362           2 2025-07-13  2781  117432.200846  119449.571906  117265.437865
# 363           1 2025-07-14  2781  119115.787510  123091.612801  118959.196786
# 364           0 2025-07-15  2781  119853.848476  119935.560408  115765.686727
#
#              close        volume     marketCap  daily_weighted_sentiment  \
# 360  117516.993668  8.692836e+10  2.337810e+12                  0.178156
# 361  117435.230053  4.552456e+10  2.335906e+12                 -0.539831
# 362  119116.117549  4.902109e+10  2.369445e+12                 -0.436295
# 363  119849.705720  1.817464e+11  2.384183e+12                 -0.157348
# 364  117777.188995  9.832166e+10  2.342931e+12                 -0.212001
#
#      comment_volume  BTC_trends    gold_spot    gspc_spot     ndx_spot
# 360            84.0        45.0  3356.000000  6259.750000  22780.59961
# 361            91.0        45.0  3356.000000  6259.750000  22780.59961
# 362            76.0        53.0  3356.000000  6259.750000  22780.59961
# 363           138.0        53.0  3351.500000  6268.560059  22855.63086
# 364            46.0        53.0  3329.800049  6243.759766  22884.58984

# %% [markdown]
# Changing target from 1,-1 to 1,0 due to deep learning model constraints

# %%
def assign_target(change):
    if pd.isna(change):
        return np.nan  
    elif change > 0:
        return 1       
    else:
        return -1

# %%
df['price_change'] = df['close'].diff()
df['next_day_price_change'] = df['price_change'].shift(-1)

# %%
df['target'] = df['next_day_price_change'].apply(assign_target)
df.drop(columns=['next_day_price_change'], inplace=True)
df.dropna(subset=['target'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0       date  name          open          high           low  \
# 0         364 2024-07-16  2781  64784.418843  65354.338200  62487.967110
# 1         363 2024-07-17  2781  65091.830709  66066.733027  63896.087193
# 2         362 2024-07-18  2781  64104.737679  65104.661419  63246.164439
# 3         361 2024-07-19  2781  63972.325499  67442.638116  63329.342025
# 4         360 2024-07-20  2781  66709.925615  67610.734373  66299.618373
#
#           close        volume     marketCap  daily_weighted_sentiment  \
# 0  65097.146831  4.161735e+10  1.284145e+12                 -0.092346
# 1  64118.792669  3.252507e+10  1.264877e+12                  0.032045
# 2  63974.066684  2.723931e+10  1.262047e+12                 -0.000932
# 3  66710.154313  3.700386e+10  1.316051e+12                  0.033252
# 4  67163.644924  1.902958e+10  1.325061e+12                  0.000000
#
#    comment_volume  BTC_trends    gold_spot    gspc_spot     ndx_spot  \
# 0            59.0        36.0  2462.399902  5667.200195  20398.61914
# 1            29.0        36.0  2454.800049  5588.270020  19799.14063
# 2            24.0        36.0  2451.800049  5544.589844  19705.08984
# 3            30.0        36.0  2395.500000  5505.000000  19522.61914
# 4             2.0        36.0  2395.500000  5505.000000  19522.61914
#
#    price_change  target
# 0           NaN    -1.0
# 1   -978.354161    -1.0
# 2   -144.725985     1.0
# 3   2736.087629     1.0
# 4    453.490611     1.0

# %% [markdown]
# ### Percentage Changes (24h, 3days, 7days)

# %%
df['percent_change_24h'] = df['close'].pct_change() * 100
df['percent_change_3d'] = df['close'].pct_change(periods=3) * 100
df['percent_change_7d'] = df['close'].pct_change(periods=7) * 100
df['percent_change_14d'] = df['close'].pct_change(periods=14) * 100

# %% [markdown]
# ### Moving Average

# %% [markdown]
# ma_7d: This feature tells the model about the level of the recent price trend. It acts as a smoothed, less noisy version of the price itself. Currently taken for 7 Days.
#
# price_vs_ma7d: This feature tells the model about the deviation from the recent trend. It measures how "overextended" or "oversold" the current price is compared to its recent average. A model might learn that when this value is extremely high (e.g., +15%), the price is likely to come back down, even if the trend is generally up.

# %%
df['ma_7d'] = df['close'].rolling(window=7).mean()
df['price_vs_ma7d'] = (df['close'] - df['ma_7d']) / df['ma_7d'] * 100

# %%
df['ma_14d'] = df['close'].rolling(window=14).mean()
df['price_vs_ma14d'] = (df['close'] - df['ma_14d']) / df['ma_14d'] * 100

# %%
df.tail()
# Out:
#      Unnamed: 0       date  name           open           high            low  \
# 359           5 2025-07-10  2781  111329.195981  116608.784676  110660.749453
# 360           4 2025-07-11  2781  115986.234797  118856.473739  115245.686349
# 361           3 2025-07-12  2781  117530.712896  118219.900043  116977.023698
# 362           2 2025-07-13  2781  117432.200846  119449.571906  117265.437865
# 363           1 2025-07-14  2781  119115.787510  123091.612801  118959.196786
#
#              close        volume     marketCap  daily_weighted_sentiment  ...  \
# 359  115987.206197  9.591161e+10  2.307032e+12                  0.525458  ...
# 360  117516.993668  8.692836e+10  2.337810e+12                  0.178156  ...
# 361  117435.230053  4.552456e+10  2.335906e+12                 -0.539831  ...
# 362  119116.117549  4.902109e+10  2.369445e+12                 -0.436295  ...
# 363  119849.705720  1.817464e+11  2.384183e+12                 -0.157348  ...
#
#      price_change  target  percent_change_24h  percent_change_3d  \
# 359   4660.654928     1.0            4.186472           7.098214
# 360   1529.787472    -1.0            1.318928           7.862961
# 361    -81.763615     1.0           -0.069576           5.487171
# 362   1680.887496     1.0            1.431332           2.697635
# 363    733.588171    -1.0            0.615860           1.985000
#
#      percent_change_7d  percent_change_14d          ma_7d  price_vs_ma7d  \
# 359           5.781436            8.439793  110008.782124       5.434497
# 360           8.777445            9.738273  111363.447070       5.525643
# 361           8.504063            9.417444  112678.311079       4.221681
# 362           9.048668            9.900347  114090.317910       4.405106
# 363          10.664700           11.867580  115740.297143       3.550543
#
#             ma_14d  price_vs_ma14d
# 359  108871.720976        6.535660
# 360  109616.618365        7.207279
# 361  110338.584570        6.431699
# 362  111105.052246        7.210352
# 363  112013.221618        6.996035
#
# [5 rows x 25 columns]

# %%
df.head(15)
# Out:
#     Unnamed: 0       date  name          open          high           low  \
# 0          364 2024-07-16  2781  64784.418843  65354.338200  62487.967110
# 1          363 2024-07-17  2781  65091.830709  66066.733027  63896.087193
# 2          362 2024-07-18  2781  64104.737679  65104.661419  63246.164439
# 3          361 2024-07-19  2781  63972.325499  67442.638116  63329.342025
# 4          360 2024-07-20  2781  66709.925615  67610.734373  66299.618373
# 5          359 2024-07-21  2781  67164.911922  68372.905166  65842.298800
# 6          358 2024-07-22  2781  68152.976133  68480.062791  66611.299868
# 7          357 2024-07-23  2781  67584.804355  67779.017554  65484.462081
# 8          356 2024-07-24  2781  65927.858075  67113.984313  65146.994976
# 9          355 2024-07-25  2781  65375.873485  66112.420035  63473.473285
# 10         354 2024-07-26  2781  65771.810417  68207.600027  65743.769435
# 11         353 2024-07-27  2781  67911.814263  69398.511308  66705.219576
# 12         352 2024-07-28  2781  67808.655588  68301.854110  67085.828187
# 13         351 2024-07-29  2781  68259.054933  69987.542208  66532.593110
# 14         350 2024-07-30  2781  66819.052658  66987.672308  65323.191979
#
#            close        volume     marketCap  daily_weighted_sentiment  ...  \
# 0   65097.146831  4.161735e+10  1.284145e+12                 -0.092346  ...
# 1   64118.792669  3.252507e+10  1.264877e+12                  0.032045  ...
# 2   63974.066684  2.723931e+10  1.262047e+12                 -0.000932  ...
# 3   66710.154313  3.700386e+10  1.316051e+12                  0.033252  ...
# 4   67163.644924  1.902958e+10  1.325061e+12                  0.000000  ...
# 5   68154.522906  2.665219e+10  1.344591e+12                  0.000000  ...
# 6   67585.249972  4.264911e+10  1.333416e+12                 -0.330237  ...
# 7   65927.672361  3.560567e+10  1.300763e+12                  0.000000  ...
# 8   65372.133234  2.747094e+10  1.289901e+12                  0.000000  ...
# 9   65777.223940  3.831576e+10  1.297746e+12                 -0.002802  ...
# 10  67912.063096  3.048863e+10  1.340006e+12                 -0.002802  ...
# 11  67813.339416  3.469191e+10  1.338003e+12                  0.000000  ...
# 12  68255.865769  1.804317e+10  1.346859e+12                  0.004175  ...
# 13  66819.916186  4.078068e+10  1.318541e+12                  0.033665  ...
# 14  66201.016226  3.138049e+10  1.306384e+12                 -0.045274  ...
#
#     price_change  target  percent_change_24h  percent_change_3d  \
# 0            NaN    -1.0                 NaN                NaN
# 1    -978.354161    -1.0           -1.502914                NaN
# 2    -144.725985     1.0           -0.225715                NaN
# 3    2736.087629     1.0            4.276870           2.477847
# 4     453.490611     1.0            0.679792           4.748767
# 5     990.877982    -1.0            1.475319           6.534611
# 6    -569.272934    -1.0           -0.835268           1.311788
# 7   -1657.577611    -1.0           -2.452573          -1.840240
# 8    -555.539128     1.0           -0.842649          -4.082473
# 9     405.090706     1.0            0.619669          -2.675178
# 10   2134.839156    -1.0            3.245560           3.009951
# 11    -98.723680     1.0           -0.145370           3.734322
# 12    442.526353    -1.0            0.652565           3.768237
# 13  -1435.949583    -1.0           -2.103775          -1.608178
# 14   -618.899960    -1.0           -0.926221          -2.377590
#
#     percent_change_7d  percent_change_14d         ma_7d  price_vs_ma7d  \
# 0                 NaN                 NaN           NaN            NaN
# 1                 NaN                 NaN           NaN            NaN
# 2                 NaN                 NaN           NaN            NaN
# 3                 NaN                 NaN           NaN            NaN
# 4                 NaN                 NaN           NaN            NaN
# 5                 NaN                 NaN           NaN            NaN
# 6                 NaN                 NaN  66114.796900       2.224091
# 7            1.275825                 NaN  66233.443404      -0.461657
# 8            1.954716                 NaN  66412.492056      -1.566511
# 9            2.818575                 NaN  66670.085950      -1.339224
# 10           1.801688                 NaN  66841.787205       1.601208
# 11           0.967331                 NaN  66934.600704       1.312832
# 12           0.148696                 NaN  66949.078256       1.951913
# 13          -1.132398                 NaN  66839.744858      -0.029666
# 14           0.414612            1.695726  66878.793981      -1.013442
#
#           ma_14d  price_vs_ma14d
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
# 5            NaN             NaN
# 6            NaN             NaN
# 7            NaN             NaN
# 8            NaN             NaN
# 9            NaN             NaN
# 10           NaN             NaN
# 11           NaN             NaN
# 12           NaN             NaN
# 13  66477.270879        0.515432
# 14  66556.118693       -0.533538
#
# [15 rows x 25 columns]

# %% [markdown]
# ### Stockstats Features

# %% [markdown]
# Implementing the stockstats library to generate financial indicator features.

# %% [markdown]
# Columns have to be renamed to fit the stockstats wrapper convention.

# %%
df.rename(columns={
    'Close': 'close',
    'High': 'high',
    'Low': 'low',
    'Open': 'open',
    'Volume': 'volume'
}, inplace=True)

df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
stock_df = Sdf.retype(df)

# %%
stock_df['close_7_ema']
stock_df['close_14_ema']
stock_df['adx']
stock_df['rsi_7']
stock_df['rsi']
stock_df['stochrsi']
stock_df['atr']
stock_df['mfi']
# Out:
# date
# 2024-07-16    0.500000
# 2024-07-17    0.500000
# 2024-07-18    0.500000
# 2024-07-19    0.500000
# 2024-07-20    0.500000
#                 ...
# 2025-07-10    0.624905
# 2025-07-11    0.713836
# 2025-07-12    0.721526
# 2025-07-13    0.728298
# 2025-07-14    0.822124
# Name: mfi, Length: 364, dtype: float64

# %%
stock_df['boll']
stock_df['boll_width'] = stock_df['boll_ub'] - stock_df['boll_lb']

# %%
stock_df['kdjk']
stock_df['kdjd']

#Checking if k line is over d line
stock_df['k_above_d'] = stock_df['kdjk'] > stock_df['kdjd']
stock_df['crossover'] = stock_df['k_above_d'].diff()

stock_df['kdj_signal'] = 0.0
# For Bullish signal
stock_df.loc[stock_df['crossover'] & stock_df['k_above_d'], 'kdj_signal'] = 1.0
# For Bearish signal
stock_df.loc[stock_df['crossover'] & ~stock_df['k_above_d'], 'kdj_signal'] = -1.0

stock_df = stock_df.drop(['k_above_d', 'crossover'], axis=1)

print(stock_df[['kdjk', 'kdjd', 'kdj_signal']].tail(10))
# Out:
#                  kdjk       kdjd  kdj_signal
# date
# 2025-07-05  67.044894  73.916183         0.0
# 2025-07-06  69.923343  72.585237         0.0
# 2025-07-07  66.070843  70.413772         0.0
# 2025-07-08  67.529358  69.452301         0.0
# 2025-07-09  75.403598  71.436066         1.0
# 2025-07-10  81.793074  74.888402         0.0
# 2025-07-11  83.999681  77.925495         0.0
# 2025-07-12  85.234989  80.361993         0.0
# 2025-07-13  89.226523  83.316836         0.0
# 2025-07-14  85.887001  84.173558         0.0

# %%
#changing default window for MACD

window=stockstats.set_dft_window('macd', (8, 20, 9))
stockstats.set_dft_window('macd', window)

# %%
stock_df = Sdf.retype(stock_df)

# %%
stock_df['macd']
# Out:
# date
# 2024-07-16       0.000000
# 2024-07-17     -21.950254
# 2024-07-18     -32.456924
# 2024-07-19      62.345275
# 2024-07-20     130.592282
#                  ...
# 2025-07-10    1644.884702
# 2025-07-11    2150.652051
# 2025-07-12    2515.877212
# 2025-07-13    2907.439207
# 2025-07-14    3239.605192
# Name: macd, Length: 364, dtype: float64

# %%
stock_df.head()
# Out:
#             name          open          high           low         close  \
# date
# 2024-07-16  2781  64784.418843  65354.338200  62487.967110  65097.146831
# 2024-07-17  2781  65091.830709  66066.733027  63896.087193  64118.792669
# 2024-07-18  2781  64104.737679  65104.661419  63246.164439  63974.066684
# 2024-07-19  2781  63972.325499  67442.638116  63329.342025  66710.154313
# 2024-07-20  2781  66709.925615  67610.734373  66299.618373  67163.644924
#
#                   volume     marketCap  daily_weighted_sentiment  \
# date
# 2024-07-16  4.161735e+10  1.284145e+12                 -0.092346
# 2024-07-17  3.252507e+10  1.264877e+12                  0.032045
# 2024-07-18  2.723931e+10  1.262047e+12                 -0.000932
# 2024-07-19  3.700386e+10  1.316051e+12                  0.033252
# 2024-07-20  1.902958e+10  1.325061e+12                  0.000000
#
#             comment_volume  BTC_trends  ...          boll       boll_ub  \
# date                                    ...
# 2024-07-16            59.0        36.0  ...  65097.146831           NaN
# 2024-07-17            29.0        36.0  ...  64607.969750  65991.571474
# 2024-07-18            24.0        36.0  ...  64396.668728  65618.533830
# 2024-07-19            30.0        36.0  ...  64975.040124  67494.468321
# 2024-07-20             2.0        36.0  ...  65412.761084  68344.080173
#
#                  boll_lb   boll_width       kdjk       kdjd  kdj_signal  \
# date
# 2024-07-16           NaN          NaN  63.675761  54.558587         0.0
# 2024-07-17  63224.368026  2767.203448  57.640339  55.585838         0.0
# 2024-07-18  63174.803626  2443.730204  52.268718  54.480131        -1.0
# 2024-07-19  62455.611928  5038.856393  63.251245  57.403836         1.0
# 2024-07-20  62481.441995  5862.638178  72.591663  62.466445         0.0
#
#                   macd      macds      macdh
# date
# 2024-07-16    0.000000   0.000000   0.000000
# 2024-07-17  -21.950254 -12.194585  -9.755668
# 2024-07-18  -32.456924 -20.498823 -11.958102
# 2024-07-19   62.345275   7.564896  54.780379
# 2024-07-20  130.592282  44.162762  86.429520
#
# [5 rows x 43 columns]

# %%
all_features_df = pd.DataFrame(stock_df)

# %%
all_features_df.dropna(inplace=True)

# %%
all_features_df.to_csv(r'C:\Users\madha\Desktop\Dissertation\Data\Master Data\Feature Engineering\FeatureEngineered_BTC.csv')
